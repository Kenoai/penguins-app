# %%
libraries = ''
with open('stenv.yml', 'r') as f:
    text = f.readlines()
    for line in text:
        if 'name: stenv' not in line and 'channels' not in line: 
            libraries += line.split('=')[0] + '\n'
        
        print(libraries)
# Out:
#   - conda-forge
#
#
#   - conda-forge
#
#   - defaults
#
#
#   - conda-forge
#
#   - defaults
#
# dependencies:
#
#
#   - conda-forge
#
#   - defaults
#
# dependencies:
#
#   - abseil-cpp
#
#   - conda-forge
#
#   - defaults
#
# dependencies:
#
#   - abseil-cpp
#   - altair
#
#   - conda-forge
#
#   - defaults
#
# dependencies:
#
#   - abseil-cpp
#   - altair
#   - appnope
#
#   - conda-forge
#
#   - defaults
#
# dependencies:
#
#   - abseil-cpp
#   - altair
#   - appnope
#   - argh
#
#   - conda-forge
#
#   - defaults
#
# dependencies:
#
#   - abseil-cpp
#   - altair
#   - appnope
#   - argh
#   - argon2-cffi
#
#   - conda-forge
#
#   - defaults
#
# dependencies:
#
#   - abseil-cpp
#   - altair
#   - appnope
#   - argh
#   - argon2-cffi
#   - argon2-cffi-bindings
#
#   - conda-forge
#
#   - defaults
#
# dependencies:
#
#   - abseil-cpp
#   - altair
#   - appnope
#   - argh
#   - argon2-cffi
#   - argon2-cffi-bindings
#   - arrow-cpp
#
#   - conda-forge
#
#   - defaults
#
# ...

# %%
Lines = file1.readlines()
  
count = 0
# Strips the newline character
for line in Lines:
    count += 1
    print("Line{}: {}".format(count, line.strip()))
